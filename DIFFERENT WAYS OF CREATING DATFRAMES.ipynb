# %%
import pandas as pd

# %%
df= pd.read_csv("weather.csv")

# %%
df
# Out:
#                       Formatted_Date        Summary Precip_Type  Temperature  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain     9.472222
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain     9.355556
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain     9.377778
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain     8.288889
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain     8.755556
# ...                              ...            ...         ...          ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain    26.016667
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain    24.583333
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain    22.038889
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain    21.522222
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain    20.438889
#
# ...

# %%
df1= pd.read_excel("weather.xlsx")

# %%
df1
# Out:
#                       Formatted_Date        Summary Precip_Type  Temperature  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain     9.472222
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain     9.355556
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain     9.377778
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain     8.288889
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain     8.755556
# ...                              ...            ...         ...          ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain    26.016667
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain    24.583333
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain    22.038889
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain    21.522222
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain    20.438889
#
# ...

# %%
weather_data={
    "Formatted_Date":['2016-09-09 20:00:00.000 +0200', '2016-09-09 20:00:00.000 +0200','2016-09-09 20:00:00.000 +0200','2016-09-09 20:00:00.000 +0200'],
    "Summary":['Partly Cloudy','Partly Cloudy','Partly Cloudy','Partly Cloudy'],
    "Temperature":[9.4722,9.3555,20.438,26.583]
}

df3=pd.DataFrame(weather_data)
df3
# Out:
#                   Formatted_Date        Summary  Temperature
# 0  2016-09-09 20:00:00.000 +0200  Partly Cloudy       9.4722
# 1  2016-09-09 20:00:00.000 +0200  Partly Cloudy       9.3555
# 2  2016-09-09 20:00:00.000 +0200  Partly Cloudy      20.4380
# 3  2016-09-09 20:00:00.000 +0200  Partly Cloudy      26.5830

# %%
weather_data=[
    ('2016-09-09 20:00:00.000 +0200', '2016-09-09 20:00:00.000 +0200','2016-09-09 20:00:00.000 +0200'),
    ('Partly Cloudy','Partly Cloudy','Partly Cloudy'),
    (9.4722,9.3555,20.438)
]

df4=pd.DataFrame(weather_data,columns=["Formatted_Date","Summary", "Temperature"])

# %%
df4
# Out:
#                   Formatted_Date                        Summary  \
# 0  2016-09-09 20:00:00.000 +0200  2016-09-09 20:00:00.000 +0200
# 1                  Partly Cloudy                  Partly Cloudy
# 2                         9.4722                         9.3555
#
#                      Temperature
# 0  2016-09-09 20:00:00.000 +0200
# 1                  Partly Cloudy
# 2                         20.438
