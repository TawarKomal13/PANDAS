# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv('weather.csv')

# %%
df
# Out:
#                       Formatted_Date        Summary Precip_Type  Temperature  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain     9.472222
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain     9.355556
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain     9.377778
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain     8.288889
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain     8.755556
# ...                              ...            ...         ...          ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain    26.016667
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain    24.583333
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain    22.038889
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain    21.522222
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain    20.438889
#
#        Apparent_Temperature   Humidity  Wind_Speed(km/h)  \
# 0                   7.388889      0.89           14.1197
# 1                   7.227778      0.86           14.2646
# 2                   9.377778      0.89            3.9284
# 3                   5.944444      0.83           14.1036
# 4                   6.977778      0.83           11.0446
# ...                      ...       ...               ...
# 96448              26.016667      0.43           10.9963
# 96449              24.583333      0.48           10.0947
# 96450              22.038889      0.56            8.9838
# 96451              21.522222      0.60           10.5294
# 96452              20.438889      0.61            5.8765
#
#        Wind_Bearing(degrees)  Visibility(km)  Loud_Cover  Pressure(millibars)  \
# 0                        251         15.8263           0              1015.13
# 1                        259         15.8263           0              1015.63
# 2                        204         14.9569           0              1015.94
# 3                        269         15.8263           0              1016.41
# 4                        259         15.8263           0              1016.51
# ...                      ...             ...         ...                  ...
# 96448                     31         16.1000           0              1014.36
# 96449                     20         15.5526           0              1015.16
# 96450                     30         16.1000           0              1015.66
# 96451                     20         16.1000           0              1015.95
# 96452                     39         15.5204           0              1016.16
#
#                                 Daily_Summary
# 0           Partly cloudy throughout the day.
# 1           Partly cloudy throughout the day.
# 2           Partly cloudy throughout the day.
# 3           Partly cloudy throughout the day.
# 4           Partly cloudy throughout the day.
# ...                                       ...
# 96448  Partly cloudy starting in the morning.
# 96449  Partly cloudy starting in the morning.
# 96450  Partly cloudy starting in the morning.
# 96451  Partly cloudy starting in the morning.
# 96452  Partly cloudy starting in the morning.
#
# [96453 rows x 12 columns]

# %%
df.shape
# Out:
# (96453, 12)

# %%
rows, columns=df.shape

# %%
rows
# Out:
# 96453

# %%
columns
# Out:
# 12

# %%
df.head()
# Out:
#                   Formatted_Date        Summary Precip_Type  Temperature  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain     9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain     9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain     9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain     8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain     8.755556
#
#    Apparent_Temperature   Humidity  Wind_Speed(km/h)  Wind_Bearing(degrees)  \
# 0               7.388889      0.89           14.1197                    251
# 1               7.227778      0.86           14.2646                    259
# 2               9.377778      0.89            3.9284                    204
# 3               5.944444      0.83           14.1036                    269
# 4               6.977778      0.83           11.0446                    259
#
#    Visibility(km)  Loud_Cover  Pressure(millibars)  \
# 0         15.8263           0              1015.13
# 1         15.8263           0              1015.63
# 2         14.9569           0              1015.94
# 3         15.8263           0              1016.41
# 4         15.8263           0              1016.51
#
#                        Daily_Summary
# 0  Partly cloudy throughout the day.
# 1  Partly cloudy throughout the day.
# 2  Partly cloudy throughout the day.
# 3  Partly cloudy throughout the day.
# 4  Partly cloudy throughout the day.

# %%
df.tail()
# Out:
#                       Formatted_Date        Summary Precip_Type  Temperature  \
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain    26.016667
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain    24.583333
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain    22.038889
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain    21.522222
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain    20.438889
#
#        Apparent_Temperature   Humidity  Wind_Speed(km/h)  \
# 96448              26.016667      0.43           10.9963
# 96449              24.583333      0.48           10.0947
# 96450              22.038889      0.56            8.9838
# 96451              21.522222      0.60           10.5294
# 96452              20.438889      0.61            5.8765
#
#        Wind_Bearing(degrees)  Visibility(km)  Loud_Cover  Pressure(millibars)  \
# 96448                     31         16.1000           0              1014.36
# 96449                     20         15.5526           0              1015.16
# 96450                     30         16.1000           0              1015.66
# 96451                     20         16.1000           0              1015.95
# 96452                     39         15.5204           0              1016.16
#
#                                 Daily_Summary
# 96448  Partly cloudy starting in the morning.
# 96449  Partly cloudy starting in the morning.
# 96450  Partly cloudy starting in the morning.
# 96451  Partly cloudy starting in the morning.
# 96452  Partly cloudy starting in the morning.

# %%
df[2:10]
# Out:
#                   Formatted_Date        Summary Precip_Type  Temperature  \
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain     9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain     8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain     8.755556
# 5  2006-04-01 05:00:00.000 +0200  Partly Cloudy        rain     9.222222
# 6  2006-04-01 06:00:00.000 +0200  Partly Cloudy        rain     7.733333
# 7  2006-04-01 07:00:00.000 +0200  Partly Cloudy        rain     8.772222
# 8  2006-04-01 08:00:00.000 +0200  Partly Cloudy        rain    10.822222
# 9  2006-04-01 09:00:00.000 +0200  Partly Cloudy        rain    13.772222
#
#    Apparent_Temperature   Humidity  Wind_Speed(km/h)  Wind_Bearing(degrees)  \
# 2               9.377778      0.89            3.9284                    204
# 3               5.944444      0.83           14.1036                    269
# 4               6.977778      0.83           11.0446                    259
# 5               7.111111      0.85           13.9587                    258
# 6               5.522222      0.95           12.3648                    259
# 7               6.527778      0.89           14.1519                    260
# 8              10.822222      0.82           11.3183                    259
# 9              13.772222      0.72           12.5258                    279
#
#    Visibility(km)  Loud_Cover  Pressure(millibars)  \
# 2         14.9569           0              1015.94
# 3         15.8263           0              1016.41
# 4         15.8263           0              1016.51
# 5         14.9569           0              1016.66
# 6          9.9820           0              1016.72
# 7          9.9820           0              1016.84
# 8          9.9820           0              1017.37
# 9          9.9820           0              1017.22
#
#                        Daily_Summary
# 2  Partly cloudy throughout the day.
# 3  Partly cloudy throughout the day.
# 4  Partly cloudy throughout the day.
# 5  Partly cloudy throughout the day.
# 6  Partly cloudy throughout the day.
# 7  Partly cloudy throughout the day.
# 8  Partly cloudy throughout the day.
# 9  Partly cloudy throughout the day.

# %%
df[:]
# Out:
#                       Formatted_Date        Summary Precip_Type  Temperature  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain     9.472222
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain     9.355556
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain     9.377778
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain     8.288889
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain     8.755556
# ...                              ...            ...         ...          ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain    26.016667
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain    24.583333
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain    22.038889
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain    21.522222
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain    20.438889
#
#        Apparent_Temperature   Humidity  Wind_Speed(km/h)  \
# 0                   7.388889      0.89           14.1197
# 1                   7.227778      0.86           14.2646
# 2                   9.377778      0.89            3.9284
# 3                   5.944444      0.83           14.1036
# 4                   6.977778      0.83           11.0446
# ...                      ...       ...               ...
# 96448              26.016667      0.43           10.9963
# 96449              24.583333      0.48           10.0947
# 96450              22.038889      0.56            8.9838
# 96451              21.522222      0.60           10.5294
# 96452              20.438889      0.61            5.8765
#
#        Wind_Bearing(degrees)  Visibility(km)  Loud_Cover  Pressure(millibars)  \
# 0                        251         15.8263           0              1015.13
# 1                        259         15.8263           0              1015.63
# 2                        204         14.9569           0              1015.94
# 3                        269         15.8263           0              1016.41
# 4                        259         15.8263           0              1016.51
# ...                      ...             ...         ...                  ...
# 96448                     31         16.1000           0              1014.36
# 96449                     20         15.5526           0              1015.16
# 96450                     30         16.1000           0              1015.66
# 96451                     20         16.1000           0              1015.95
# 96452                     39         15.5204           0              1016.16
#
#                                 Daily_Summary
# 0           Partly cloudy throughout the day.
# 1           Partly cloudy throughout the day.
# 2           Partly cloudy throughout the day.
# 3           Partly cloudy throughout the day.
# 4           Partly cloudy throughout the day.
# ...                                       ...
# 96448  Partly cloudy starting in the morning.
# 96449  Partly cloudy starting in the morning.
# 96450  Partly cloudy starting in the morning.
# 96451  Partly cloudy starting in the morning.
# 96452  Partly cloudy starting in the morning.
#
# [96453 rows x 12 columns]

# %%
df.columns
# Out:
# Index(['Formatted_Date', 'Summary', 'Precip_Type', 'Temperature',
#        'Apparent_Temperature ', 'Humidity', 'Wind_Speed(km/h)',
#        'Wind_Bearing(degrees)', 'Visibility(km)', 'Loud_Cover',
#        'Pressure(millibars)', 'Daily_Summary'],
#       dtype='object')

# %%
df['Formatted_Date']
# Out:
# 0        2006-04-01 00:00:00.000 +0200
# 1        2006-04-01 01:00:00.000 +0200
# 2        2006-04-01 02:00:00.000 +0200
# 3        2006-04-01 03:00:00.000 +0200
# 4        2006-04-01 04:00:00.000 +0200
#                      ...
# 96448    2016-09-09 19:00:00.000 +0200
# 96449    2016-09-09 20:00:00.000 +0200
# 96450    2016-09-09 21:00:00.000 +0200
# 96451    2016-09-09 22:00:00.000 +0200
# 96452    2016-09-09 23:00:00.000 +0200
# Name: Formatted_Date, Length: 96453, dtype: object

# %%
df[['Formatted_Date','Temperature','Humidity']]
# Out:
#                       Formatted_Date  Temperature  Humidity
# 0      2006-04-01 00:00:00.000 +0200     9.472222      0.89
# 1      2006-04-01 01:00:00.000 +0200     9.355556      0.86
# 2      2006-04-01 02:00:00.000 +0200     9.377778      0.89
# 3      2006-04-01 03:00:00.000 +0200     8.288889      0.83
# 4      2006-04-01 04:00:00.000 +0200     8.755556      0.83
# ...                              ...          ...       ...
# 96448  2016-09-09 19:00:00.000 +0200    26.016667      0.43
# 96449  2016-09-09 20:00:00.000 +0200    24.583333      0.48
# 96450  2016-09-09 21:00:00.000 +0200    22.038889      0.56
# 96451  2016-09-09 22:00:00.000 +0200    21.522222      0.60
# 96452  2016-09-09 23:00:00.000 +0200    20.438889      0.61
#
# [96453 rows x 3 columns]

# %%
df['Temperature'].max()
# Out:
# 39.90555556

# %%
df['Temperature'].min()
# Out:
# -21.82222222

# %%
df['Temperature'].mean()
# Out:
# 11.932678437519867

# %%
df['Temperature'].std()
# Out:
# 9.55154632065509

# %%
df.describe()
# Out:
#         Temperature  Apparent_Temperature       Humidity  Wind_Speed(km/h)  \
# count  96453.000000           96453.000000  96453.000000      96453.000000
# mean      11.932678              10.855029      0.734899         10.810640
# std        9.551546              10.696847      0.195473          6.913571
# min      -21.822222             -27.716667      0.000000          0.000000
# 25%        4.688889               2.311111      0.600000          5.828200
# 50%       12.000000              12.000000      0.780000          9.965900
# 75%       18.838889              18.838889      0.890000         14.135800
# max       39.905556              39.344444      1.000000         63.852600
#
#        Wind_Bearing(degrees)  Visibility(km)  Loud_Cover  Pressure(millibars)
# count           96453.000000    96453.000000     96453.0         96453.000000
# mean              187.509232       10.347325         0.0          1003.235956
# std               107.383428        4.192123         0.0           116.969906
# min                 0.000000        0.000000         0.0             0.000000
# 25%               116.000000        8.339800         0.0          1011.900000
# 50%               180.000000       10.046400         0.0          1016.450000
# 75%               290.000000       14.812000         0.0          1021.090000
# max               359.000000       16.100000         0.0          1046.380000

# %%
df[df.Temperature>=32]
# Out:
#                       Formatted_Date        Summary Precip_Type  Temperature  \
# 732    2006-08-01 12:00:00.000 +0200  Mostly Cloudy        rain    32.172222
# 733    2006-08-01 13:00:00.000 +0200  Mostly Cloudy        rain    32.127778
# 735    2006-08-01 15:00:00.000 +0200  Mostly Cloudy        rain    32.538889
# 737    2006-08-01 17:00:00.000 +0200  Mostly Cloudy        rain    32.011111
# 952    2006-08-18 16:00:00.000 +0200  Mostly Cloudy        rain    32.172222
# ...                              ...            ...         ...          ...
# 92507  2016-06-26 14:00:00.000 +0200  Mostly Cloudy        rain    32.033333
# 92508  2016-06-26 15:00:00.000 +0200  Mostly Cloudy        rain    32.622222
# 92509  2016-06-26 16:00:00.000 +0200  Mostly Cloudy        rain    32.644444
# 92510  2016-06-26 17:00:00.000 +0200  Mostly Cloudy        rain    32.394444
# 95797  2016-09-11 16:00:00.000 +0200  Mostly Cloudy        rain    32.000000
#
#        Apparent_Temperature   Humidity  Wind_Speed(km/h)  \
# 732                32.222222      0.38            7.7280
# 733                31.272222      0.32            7.3416
# 735                32.688889      0.38           12.6224
# 737                32.511111      0.41            8.9194
# 952                32.911111      0.42           16.2932
# ...                      ...       ...               ...
# 92507              32.072222      0.39           10.8997
# 92508              33.361111      0.41            7.0357
# 92509              32.800000      0.38            4.8622
# 92510              32.538889      0.38            3.6064
# 95797              31.283333      0.34           12.6546
#
#        Wind_Bearing(degrees)  Visibility(km)  Loud_Cover  Pressure(millibars)  \
# 732                      161         10.0464           0              1010.47
# 733                      249         10.0464           0              1010.07
# 735                      199         11.2700           0              1008.95
# 737                      210         10.3523           0              1007.57
# 952                      211          9.9820           0              1012.52
# ...                      ...             ...         ...                  ...
# 92507                    165         15.5526           0              1013.18
# 92508                    235         15.8263           0              1012.73
# 92509                    239         15.8263           0              1012.33
# 92510                    266         10.3523           0              1012.08
# 95797                     10          9.9820           0              1016.43
#
#                                            Daily_Summary
# 732                    Partly cloudy starting overnight.
# 733                    Partly cloudy starting overnight.
# 735                    Partly cloudy starting overnight.
# 737                    Partly cloudy starting overnight.
# 952    Partly cloudy starting overnight continuing un...
# ...                                                  ...
# 92507                           Partly cloudy overnight.
# 92508                           Partly cloudy overnight.
# 92509                           Partly cloudy overnight.
# 92510                           Partly cloudy overnight.
# 95797                  Mostly cloudy throughout the day.
#
# [1592 rows x 12 columns]

# %%
df[df.Temperature==df.Temperature.max()]
# Out:
#                       Formatted_Date Summary Precip_Type  Temperature  \
# 12759  2007-07-22 15:00:00.000 +0200   Clear        rain    39.905556
#
#        Apparent_Temperature   Humidity  Wind_Speed(km/h)  \
# 12759              37.538889      0.13           23.5865
#
#        Wind_Bearing(degrees)  Visibility(km)  Loud_Cover  Pressure(millibars)  \
# 12759                    250           9.982           0              1007.55
#
#                                   Daily_Summary
# 12759  Partly cloudy starting in the afternoon.

# %%
df[['Formatted_Date','Temperature']][df.Temperature==df.Temperature.max()]
# Out:
#                       Formatted_Date  Temperature
# 12759  2007-07-22 15:00:00.000 +0200    39.905556

# %%
df
# Out:
#                       Formatted_Date        Summary Precip_Type  Temperature  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain     9.472222
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain     9.355556
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain     9.377778
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain     8.288889
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain     8.755556
# ...                              ...            ...         ...          ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain    26.016667
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain    24.583333
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain    22.038889
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain    21.522222
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain    20.438889
#
#        Apparent_Temperature   Humidity  Wind_Speed(km/h)  \
# 0                   7.388889      0.89           14.1197
# 1                   7.227778      0.86           14.2646
# 2                   9.377778      0.89            3.9284
# 3                   5.944444      0.83           14.1036
# 4                   6.977778      0.83           11.0446
# ...                      ...       ...               ...
# 96448              26.016667      0.43           10.9963
# 96449              24.583333      0.48           10.0947
# 96450              22.038889      0.56            8.9838
# 96451              21.522222      0.60           10.5294
# 96452              20.438889      0.61            5.8765
#
#        Wind_Bearing(degrees)  Visibility(km)  Loud_Cover  Pressure(millibars)  \
# 0                        251         15.8263           0              1015.13
# 1                        259         15.8263           0              1015.63
# 2                        204         14.9569           0              1015.94
# 3                        269         15.8263           0              1016.41
# 4                        259         15.8263           0              1016.51
# ...                      ...             ...         ...                  ...
# 96448                     31         16.1000           0              1014.36
# 96449                     20         15.5526           0              1015.16
# 96450                     30         16.1000           0              1015.66
# 96451                     20         16.1000           0              1015.95
# 96452                     39         15.5204           0              1016.16
#
#                                 Daily_Summary
# 0           Partly cloudy throughout the day.
# 1           Partly cloudy throughout the day.
# 2           Partly cloudy throughout the day.
# 3           Partly cloudy throughout the day.
# 4           Partly cloudy throughout the day.
# ...                                       ...
# 96448  Partly cloudy starting in the morning.
# 96449  Partly cloudy starting in the morning.
# 96450  Partly cloudy starting in the morning.
# 96451  Partly cloudy starting in the morning.
# 96452  Partly cloudy starting in the morning.
#
# [96453 rows x 12 columns]

# %%
df.index
# Out:
# RangeIndex(start=0, stop=96453, step=1)

# %%
df.set_index('Formatted_Date', inplace=True)

# %%
df
# Out:
#                                      Summary Precip_Type  Temperature  \
# Formatted_Date
# 2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain     9.472222
# 2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain     9.355556
# 2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain     9.377778
# 2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain     8.288889
# 2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain     8.755556
# ...                                      ...         ...          ...
# 2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain    26.016667
# 2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain    24.583333
# 2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain    22.038889
# 2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain    21.522222
# 2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain    20.438889
#
#                                Apparent_Temperature   Humidity  \
# Formatted_Date
# 2006-04-01 00:00:00.000 +0200               7.388889      0.89
# 2006-04-01 01:00:00.000 +0200               7.227778      0.86
# 2006-04-01 02:00:00.000 +0200               9.377778      0.89
# 2006-04-01 03:00:00.000 +0200               5.944444      0.83
# 2006-04-01 04:00:00.000 +0200               6.977778      0.83
# ...                                              ...       ...
# 2016-09-09 19:00:00.000 +0200              26.016667      0.43
# 2016-09-09 20:00:00.000 +0200              24.583333      0.48
# 2016-09-09 21:00:00.000 +0200              22.038889      0.56
# 2016-09-09 22:00:00.000 +0200              21.522222      0.60
# 2016-09-09 23:00:00.000 +0200              20.438889      0.61
#
#                                Wind_Speed(km/h)  Wind_Bearing(degrees)  \
# Formatted_Date
# 2006-04-01 00:00:00.000 +0200           14.1197                    251
# 2006-04-01 01:00:00.000 +0200           14.2646                    259
# 2006-04-01 02:00:00.000 +0200            3.9284                    204
# 2006-04-01 03:00:00.000 +0200           14.1036                    269
# 2006-04-01 04:00:00.000 +0200           11.0446                    259
# ...                                         ...                    ...
# 2016-09-09 19:00:00.000 +0200           10.9963                     31
# 2016-09-09 20:00:00.000 +0200           10.0947                     20
# 2016-09-09 21:00:00.000 +0200            8.9838                     30
# 2016-09-09 22:00:00.000 +0200           10.5294                     20
# 2016-09-09 23:00:00.000 +0200            5.8765                     39
#
#                                Visibility(km)  Loud_Cover  \
# Formatted_Date
# 2006-04-01 00:00:00.000 +0200         15.8263           0
# 2006-04-01 01:00:00.000 +0200         15.8263           0
# 2006-04-01 02:00:00.000 +0200         14.9569           0
# 2006-04-01 03:00:00.000 +0200         15.8263           0
# 2006-04-01 04:00:00.000 +0200         15.8263           0
# ...                                       ...         ...
# 2016-09-09 19:00:00.000 +0200         16.1000           0
# 2016-09-09 20:00:00.000 +0200         15.5526           0
# 2016-09-09 21:00:00.000 +0200         16.1000           0
# 2016-09-09 22:00:00.000 +0200         16.1000           0
# 2016-09-09 23:00:00.000 +0200         15.5204           0
#
#                                Pressure(millibars)  \
# Formatted_Date
# 2006-04-01 00:00:00.000 +0200              1015.13
# 2006-04-01 01:00:00.000 +0200              1015.63
# 2006-04-01 02:00:00.000 +0200              1015.94
# 2006-04-01 03:00:00.000 +0200              1016.41
# 2006-04-01 04:00:00.000 +0200              1016.51
# ...                                            ...
# 2016-09-09 19:00:00.000 +0200              1014.36
# 2016-09-09 20:00:00.000 +0200              1015.16
# 2016-09-09 21:00:00.000 +0200              1015.66
# 2016-09-09 22:00:00.000 +0200              1015.95
# 2016-09-09 23:00:00.000 +0200              1016.16
#
#                                                         Daily_Summary
# Formatted_Date
# 2006-04-01 00:00:00.000 +0200       Partly cloudy throughout the day.
# 2006-04-01 01:00:00.000 +0200       Partly cloudy throughout the day.
# 2006-04-01 02:00:00.000 +0200       Partly cloudy throughout the day.
# 2006-04-01 03:00:00.000 +0200       Partly cloudy throughout the day.
# 2006-04-01 04:00:00.000 +0200       Partly cloudy throughout the day.
# ...                                                               ...
# 2016-09-09 19:00:00.000 +0200  Partly cloudy starting in the morning.
# 2016-09-09 20:00:00.000 +0200  Partly cloudy starting in the morning.
# 2016-09-09 21:00:00.000 +0200  Partly cloudy starting in the morning.
# 2016-09-09 22:00:00.000 +0200  Partly cloudy starting in the morning.
# 2016-09-09 23:00:00.000 +0200  Partly cloudy starting in the morning.
#
# [96453 rows x 11 columns]

# %%
df.loc['2006-04-01 00:00:00.000 +0200']
# Out:
# Summary                                      Partly Cloudy
# Precip_Type                                           rain
# Temperature                                       9.472222
# Apparent_Temperature                              7.388889
# Humidity                                              0.89
# Wind_Speed(km/h)                                   14.1197
# Wind_Bearing(degrees)                                  251
# Visibility(km)                                     15.8263
# Loud_Cover                                               0
# Pressure(millibars)                                1015.13
# Daily_Summary            Partly cloudy throughout the day.
# Name: 2006-04-01 00:00:00.000 +0200, dtype: object

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#                       Formatted_Date        Summary Precip_Type  Temperature  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain     9.472222
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain     9.355556
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain     9.377778
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain     8.288889
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain     8.755556
# ...                              ...            ...         ...          ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain    26.016667
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain    24.583333
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain    22.038889
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain    21.522222
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain    20.438889
#
#        Apparent_Temperature   Humidity  Wind_Speed(km/h)  \
# 0                   7.388889      0.89           14.1197
# 1                   7.227778      0.86           14.2646
# 2                   9.377778      0.89            3.9284
# 3                   5.944444      0.83           14.1036
# 4                   6.977778      0.83           11.0446
# ...                      ...       ...               ...
# 96448              26.016667      0.43           10.9963
# 96449              24.583333      0.48           10.0947
# 96450              22.038889      0.56            8.9838
# 96451              21.522222      0.60           10.5294
# 96452              20.438889      0.61            5.8765
#
#        Wind_Bearing(degrees)  Visibility(km)  Loud_Cover  Pressure(millibars)  \
# 0                        251         15.8263           0              1015.13
# 1                        259         15.8263           0              1015.63
# 2                        204         14.9569           0              1015.94
# 3                        269         15.8263           0              1016.41
# 4                        259         15.8263           0              1016.51
# ...                      ...             ...         ...                  ...
# 96448                     31         16.1000           0              1014.36
# 96449                     20         15.5526           0              1015.16
# 96450                     30         16.1000           0              1015.66
# 96451                     20         16.1000           0              1015.95
# 96452                     39         15.5204           0              1016.16
#
#                                 Daily_Summary
# 0           Partly cloudy throughout the day.
# 1           Partly cloudy throughout the day.
# 2           Partly cloudy throughout the day.
# 3           Partly cloudy throughout the day.
# 4           Partly cloudy throughout the day.
# ...                                       ...
# 96448  Partly cloudy starting in the morning.
# 96449  Partly cloudy starting in the morning.
# 96450  Partly cloudy starting in the morning.
# 96451  Partly cloudy starting in the morning.
# 96452  Partly cloudy starting in the morning.
#
# [96453 rows x 12 columns]
